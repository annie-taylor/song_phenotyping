# %%
import os
import pandas as pd

from C_embedding import calculate_adaptive_workers_improved

path_to_xfoster_from_db = os.path.join('/Users','annietaylor', 'Documents', 'ucsf', 'brainard', 'x-foster' '/cross_fostered_birds_summary_with_xfoster_status.csv')

# %%
xfosters_from_db = pd.read_csv(path_to_xfoster_from_db)

# %%
gmm_birds = ['or76bk11',
'bk34bk51',
'pk24bu3',
'bk94bk87',
'rd92gr54',
'ye25',
'gr99or87',
'pk15bk43',
'pu61bk41',
'rd95wh29',
'pu10bk94',
'pk54gr20',
'ye1',
'wh58pk1',
'or8bk49',
'gr26gr95',
'ye53ye83',
'ye27ye33',
'wh99pk7',
'wh94or25',
'wh94or11',
'wh89pk4',
'wh89or12',
'wh88pk84',
'wh88br85',
'wh83pk50',
'wh82pk41',
'wh80or5',
'wh75pk99',
'wh70pk50',
'wh69pk82',
'wh67pk20',
'wh66pk94',
'wh61pk3',
'wh59pk66',
'wh57pk61',
'wh54pk85',
'wh51or31',
'wh50pk34',
'wh3pk86',
'wh39or13',
'wh35pk25',
'wh28pk28',
'wh28or1',
'wh26pk33',
'wh23pk78',
'wh21pk15',
'wh11pk95',
'rd94wh47',
'rd93wh89',
'rd93wh64',
'rd88wh69',
'rd7wh75',
'rd78wh86',
'rd78wh62',
'rd77gr82',
'rd70wh90',
'rd63wh86',
'rd62wh35',
'rd61wh68',
'rd58wh32',
'rd4wh53',
'rd3wh90',
'rd34wh20',
'rd2wh49',
'rd28wh69',
'rd26wh66',
'rd26wh34',
'rd22wh20',
'rd10wh46',
'pu88bk78',
'pu81bk1',
'pu71wh42',
'pu64wh91',
'pu62wh53',
'pu51wh43',
'pu42bk10',
'pu39wh79',
'pu31bk90',
'pu27wh16',
'pu26wh18',
'pu25wh17',
'pu22wh17',
'pu20wh66',
'pu1wh51',
'pu1wh14',
'pu19wh65',
'pu16wh31',
'pu11bk28',
'pk97rd22',
'pk74gr77',
'pk43gr64',
'pk36gr15',
'pk1gr62',
'pk18gr79',
'or67or64',
'or41or32',
'or33or33',
'or28bu17',
'or14or56',
'or100or7',
'gr94gr1',
'gr89gr73',
'gr85gr34',
'gr82gr37',
'gr78gr76',
'gr70gr66',
'gr66gr43',
'gr65gr9',
'gr63gr76',
'gr57gr47',
'gr43gr62',
'gr38gr59',
'gr37gr41',
'gr34gr22',
'gr27gr28',
'gr25gr27',
'gr24gr26',
'bu95or85',
'bu92or63',
'bu91or64',
'bu82or62',
'bu81or63',
'bu71or60',
'bu69or87',
'bu66or8',
'bu65or7',
'bu50or44',
'bu49or82',
'bu48or83',
'bu28or67',
'bu21or96',
'bu17or20',
'bu11or68',
'bk9bk8',
'bk92bk23',
'bk89bk88',
'bk86bk62',
'bk84bk85',
'bk83bk73',
'bk83bk48',
'bk79bk82',
'bk73bk71',
'bk67bk44',
'bk65bk85',
'bk64bk65',
'bk61bk26',
'bk5bk60',
'bk5bk25',
'bk51bk59',
'bk50bk49',
'bk4bk95',
'bk4bk47',
'bk47bk40',
'bk43bk70',
'bk41bk14',
'bk38bk39',
'bk36bk37',
'bk34bk33',
'bk31bk89',
'bk30bk40',
'bk2bk10',
'bk29bk8',
'bk28bk68',
'bk20bk45',
'bk1bk9',
'bk1bk3',
'bk13bk12',
'bk100bk99',]

# %%
bird_in_xfosters_from_db = {}
xfosters_from_db_names = list(xfosters_from_db['Bird Name'])
parents_from_db_names = list(xfosters_from_db['Genetic Father']) + list(xfosters_from_db['Genetic Mother']) + list(xfosters_from_db['Nest Father']) + list(xfosters_from_db['Nest Mother'])
for bird in gmm_birds:
    if (bird in xfosters_from_db_names) or (bird in parents_from_db_names):
        bird_in_xfosters_from_db[bird] = True
    else:
        bird_in_xfosters_from_db[bird] = False
print(bird_in_xfosters_from_db)

# %%
missing_birds = []
overlap_birds = []
for bird, value in bird_in_xfosters_from_db.items():
    if not value:
        missing_birds.append(bird)
    else:
        overlap_birds.append(bird)
print(len(missing_birds))
print(len(overlap_birds))
# Out:
# 95
# 74

# %%
xfosters_from_db
# Out:
#     Bird Name   Valid x-foster?                      X-foster notes Sex  \
# 0    bk75wh10               1.0   Fostered from N26, date not given   F
# 1    bk77wh12               1.0   Fostered from N26, date not given   M
# 2    pu75pu50               1.0  Fostered from N226, date not given   M
# 3    pu76pu78               1.0   Fostered from N26, date not given   M
# 4     pu5pu40               1.0                                  1d   M
# ..        ...               ...                                 ...  ..
# 610  pk12bk50               NaN                                 NaN   F
# 611  pk42bk32               NaN                                 NaN   F
# 612  or86pu73               NaN                                 NaN   F
# 613  pk75gr72               NaN                                 NaN   F
# 614  wh93or49               NaN                                 NaN   F
#
#             DOB Genetic Father Genetic Mother Nest Father Nest Mother  \
# 0    2023-11-07       pu91wh67        gr3gr64     bu81wh2    wh97wh81
# 1    2023-11-07       pu91wh67        gr3gr64     bu81wh2    wh97wh81
# 2    2023-10-12       gr97bu74        bu8wh68    bu31or27     gr8gr88
# 3    2023-10-12       gr97bu74        bu8wh68    bu31or27     gr8gr88
# 4    2023-10-12       gr97bu74        bu8wh68    bu31or27     gr8gr88
# ..          ...            ...            ...         ...         ...
# 610  2007-07-14       rd75wh72       or94bk73    bk37wh86    bu10bu33
# 611  2007-07-12       rd75wh72       or94bk73    bk37wh86    bu10bu33
# 612  2007-06-07       wh58wh78        pk95rd3    wh52wh44    gr82gr23
# 613  2007-05-26       or10bk88       bu93or82    pk54gr20    pu33bk14
# 614  2007-03-08        rd7pu84       bk34wh47    wh58wh78     pk95rd3
#
#      Total Songs                               Directories Searched
# 0           5316           /Volumes/users/public/screening/bk75wh10
# 1           7082           /Volumes/users/public/screening/bk77wh12
# 2           2335           /Volumes/users/public/screening/pu75pu50
# 3           2160           /Volumes/users/public/screening/pu76pu78
# 4           6100            /Volumes/users/public/screening/pu5pu40
# ..           ...                                                ...
# 610            4  /Volumes/users/public/Solitary call screening/...
# 611            4  /Volumes/users/public/from_stork/stork/screeni...
# 612            0                                No audio data found
# 613            0                                                NaN
# 614            0                                No audio data found
#
# [615 rows x 11 columns]

# %%
valid_xfosters = xfosters_from_db[xfosters_from_db[' Valid x-foster?'] == 1]
valid_male_xfosters = valid_xfosters[valid_xfosters['Sex'] != 'F']  # not condition to include U birds

# %%
xfosters_from_db.columns.to_list()
# Out:
# ['Bird Name',
#  ' Valid x-foster?',
#  'X-foster notes',
#  'Sex',
#  'DOB',
#  'Genetic Father',
#  'Genetic Mother',
#  'Nest Father',
#  'Nest Mother',
#  'Total Songs',
#  'Directories Searched']

# %%
# %%sql

# %%
candidate_fathers_nest = valid_male_xfosters['Nest Father']
candidate_fatehrs_gen = valid_male_xfosters['Genetic Father']

# %%
import numpy as np

fathers_nest, counts_nest  = np.unique(candidate_fathers_nest, return_counts=True)
fathers_gen, counts_gen = np.unique(candidate_fatehrs_gen, return_counts=True)

# %%
fathers_nest_sorted = fathers_nest[counts_nest >= 5]
counts_nest_sorted = counts_nest[counts_nest >= 5]
fathers_gen_sorted = fathers_gen[counts_gen >= 5]
counts_gen_sorted = counts_gen[counts_gen >= 5]

# %%
print([fathers_nest_sorted, counts_nest_sorted])
print([fathers_gen_sorted, counts_gen_sorted])
# Out:
# [array(['bk1bk3', 'bk34bk51', 'bk37wh86', 'bu10wh86', 'bu24wh84',
#        'bu7wh67', 'gr73gr72', 'gr99or87', 'or10bk88', 'pk100bk68',
#        'pk24bu3', 'pu23wh38', 'pu35wh17', 'rd81wh45', 'ye25'],
#       dtype=object), array([ 7,  5, 11, 10,  5,  5,  7,  8,  5, 10, 14,  9,  7,  5,  6])]
# [array(['bu34or18', 'pk24bu3', 'pk72bk90', 'pk85gr19', 'pk97rd22',
#        'pu11bk85', 'pu42wh35', 'pu91wh67', 'rd75wh72', 'wh71br49',
#        'wh88br85', 'ye1tut0', 'ye81br444'], dtype=object), array([ 5,  7,  7,  8,  9, 17, 10,  8, 16,  6, 15,  9,  8])]

# %%
valid_male_xfosters_from_big_families = valid_male_xfosters[valid_male_xfosters['Nest Father'].isin(fathers_nest_sorted) & valid_male_xfosters['Genetic Father'].isin(fathers_gen_sorted)]

# %%
list(valid_male_xfosters_from_big_families['Bird Name'])
# Out:
# ['wh15wh94',
#  'wh14wh93',
#  'wh50wh90',
#  'wh49wh89',
#  'wh47wh87',
#  'wh48wh88',
#  'bu26wh39',
#  'bu25wh38',
#  'bu82wh76',
#  'rd39wh3',
#  'rd40wh4',
#  'bu9wh89',
#  'bu10wh90',
#  'bu7wh87',
#  'rd33wh42',
#  'rd25wh57',
#  'gr6gr5',
#  'ye30ye82',
#  'ye23ye43',
#  'rd42pu47',
#  'rd43pu46',
#  'rd50gr1',
#  'rd39gr23',
#  'bk45wh59',
#  'wh86or19',
#  'wh85or81',
#  'wh82or15',
#  'wh83or16',
#  'rd77wh77',
#  'bk24wh25',
#  'bk100wh89',
#  'bk17wh56',
#  'bk81wh20',
#  'bk79wh14',
#  'bk38bk39',
#  'bk4bk47',
#  'bk36bk37',
#  'bk83bk73',
#  'bk94bk87',
#  'bk67bk44',
#  'bk76bk63',
#  'bk75bk62',
#  'bk43bk70',
#  'bk13bk12',
#  'bk41bk14',
#  'pk61bk8',
#  'pk15bk43',
#  'pu57wh52',
#  'pu55wh32',
#  'ye92br4',
#  'ye93br5',
#  'ye91br6',
#  'bk34bk51',
#  'bk73bk71',
#  'bk1bk3',
#  'bk91wh31',
#  'bk61wh42',
#  'bk63wh43',
#  'pu1wh51',
#  'wh93pk62',
#  'wh91pk61',
#  'pk6bk65',
#  'pk37bk19',
#  'pk46bk46',
#  'bk40wh47',
#  'pu31br476',
#  'pu33br479',
#  'pk5bk39',
#  'pk2bk37',
#  'pu58br33',
#  'pu55br34',
#  'pu22wh17',
#  'pk1bk31',
#  'pk43bk33',
#  'pu51wh43',
#  'pu71wh42',
#  'pu39wh79',
#  'bk13wh63',
#  'bk72wh64',
#  'bk74wh76']

# %%
path_to_home_reared_from_db = os.path.join('/Users','annietaylor', 'Documents', 'ucsf', 'brainard', 'x-foster' '/home_reared_offspring.csv')

# %%
home_reared_df = pd.read_csv(path_to_home_reared_from_db)

# %%
home_reared_subset = home_reared_df[home_reared_df['Nest Father'].isin(fathers_nest_sorted) | home_reared_df['Genetic Father'].isin(fathers_gen_sorted)]

# %%
list(home_reared_subset['Bird Name'])
# Out:
# ['rd15wh42',
#  'rd66wh41',
#  'rd79wh31',
#  'rd3wh90',
#  'rd70wh17',
#  'rd88wh69',
#  'rd94wh47',
#  'rd26wh66',
#  'rd58wh32',
#  'rd25wh83',
#  'rd42wh7',
#  'rd42wh61',
#  'rd25wh42',
#  'rd78wh62',
#  'rd89wh68',
#  'rd11wh87',
#  'rd68wh16',
#  'rd22wh20',
#  'rd67wh30',
#  'bk33wh45',
#  'rd69wh90',
#  'rd76wh76',
#  'rd93wh46',
#  'rd24wh3',
#  'rd26wh18',
#  'rd44wh13',
#  'rd93wh64',
#  'rd59wh41',
#  'rd75wh75',
#  'rd7wh75',
#  'rd4wh53',
#  'rd43wh12',
#  'rd34wh20',
#  'rd80wh90',
#  'rd58wh18',
#  'rd70wh90',
#  'rd78wh86',
#  'pk39rd95',
#  'pk3rd79',
#  'pk40rd96',
#  'pk35rd91',
#  'pk38rd27',
#  'pk21rd87',
#  'pk24rd90',
#  'pk41rd93',
#  'pk87rd29',
#  'pk62rd65',
#  'pk22rd88',
#  'pk37rd93',
#  'pk36rd92',
#  'pk42rd94',
#  'pk97rd30',
#  'pk2rd78',
#  'pk43rd96',
#  'pk81rd39',
#  'pk41rd28',
#  'pk1rd77',
#  'pk38rd94',
#  'pk23rd89',
#  'wh14or52',
#  'wh4or36',
#  'wh1or21',
#  'wh66or65',
#  'wh96or24',
#  'wh87or32',
#  'wh73or43',
#  'wh24or73',
#  'wh61or80',
#  'wh2or29',
#  'wh47or4',
#  'wh97or99',
#  'wh53or51',
#  'wh28or18',
#  'wh81or42',
#  'wh16or36',
#  'wh23or72',
#  'wh66or31',
#  'wh29or17',
#  'wh71or47',
#  'wh48or5',
#  'wh46or3',
#  'wh92or15',
#  'wh29or19',
#  'wh100or19',
#  'wh2or79',
#  'wh2or34',
#  'wh25or74',
#  'wh21or2',
#  'wh28or21',
#  'wh22or71',
#  'wh81or21',
#  'wh27or49',
#  'wh26or75',
#  'bk15bk14',
#  'bk5bk25',
#  'bk49bk19',
#  'bk20bk45',
#  'bk41bk11',
#  'bk100bk99',
#  'bk11bk12',
#  'bk34bk33',
#  'bk18bk40',
#  'bk17bk30',
#  'bk36bk39',
#  'bk43',
#  'bk43bk44',
#  'bk38bk2',
#  'bk50bk49',
#  'bk6bk38',
#  'bk46',
#  'bk6bk5',
#  'pu40pu75',
#  'gr25bu21',
#  'gr17bu22',
#  'gr73bu51',
#  'bu82or94',
#  'rd19rd94',
#  'or6bk93',
#  'rd63rd64',
#  'rd8rd56',
#  'rd62rd61',
#  'rd7rd55',
#  'bk34wh47',
#  'rd67rd66',
#  'bu61bu62',
#  'bk63wh90',
#  'bu10wh86',
#  'bu10wh70',
#  'bu7wh84',
#  'bu8wh68',
#  'bu7wh67',
#  'bu76wh12',
#  'bu77wh13',
#  'bu5wh83',
#  'bu81wh2',
#  'bu9wh69',
#  'bu75wh11',
#  'pu1wh14',
#  'pu26wh18',
#  'pu10wh67',
#  'pu62wh35',
#  'pu25wh17',
#  'pu48wh46',
#  'pu62wh53',
#  'pu64wh91',
#  'pu19wh65',
#  'pu20wh66',
#  'pu59wh45',
#  'pu28wh19',
#  'pu23wh38',
#  'pu40wh21',
#  'pu84wh4',
#  'pu44wh52',
#  'pu68wh32',
#  'pu61wh52',
#  'pu16wh31',
#  'bk31wh10',
#  'bk21wh11',
#  'bk17wh89',
#  'bk20wh45',
#  'bk91wh95',
#  'bk35wh47',
#  'bk80wh69',
#  'bk48wh30',
#  'bk22wh73',
#  'bk22wh12',
#  'bk28wh6',
#  'bk32wh44',
#  'bk29wh86',
#  'bk24wh14',
#  'bk23wh13',
#  'pk100bk68',
#  'pk48bk68',
#  'pk7bk27',
#  'pk72bk90',
#  'pk42bk69',
#  'pk28bk66',
#  'pk91bk68',
#  'pk41bk66',
#  'pk100bk45',
#  'pk21bk96',
#  'pk86bk94',
#  'pk30bk79',
#  'pk6rd52',
#  'pk10rd12',
#  'pk88rd26',
#  'pk62rd9',
#  'pk51rd30',
#  'pk28rd52',
#  'pk31rd19',
#  'pk47rd17',
#  'pk52rd97',
#  'pk7rd57',
#  'pk91rd61',
#  'pk18rd39',
#  'pk17rd59',
#  'pk48rd5',
#  'pk99rd81',
#  'pk52rd31',
#  'pk15rd27',
#  'pk72rd21',
#  'pk84rd63',
#  'pk84rd82',
#  'pk16rd65',
#  'pk78rd47',
#  'pk80rd49',
#  'pk16rd26',
#  'pk52rd22',
#  'pk97rd51',
#  'pk27rd32',
#  'pk14rd12',
#  'pk59rd72',
#  'pk92rd62',
#  'pk49rd6',
#  'pk25rd67',
#  'pk61rd14',
#  'pk63rd10',
#  'pk47rd23',
#  'pk15rd70',
#  'pk60rd76',
#  'pk79rd48',
#  'pk86rd23',
#  'pk92rd24',
#  'pk53rd98',
#  'pk55rd100',
#  'pk76rd94',
#  'pk29rd53',
#  'pk85rd62',
#  'pk81rd50',
#  'pk81rd39',
#  'pk64rd11',
#  'pk21rd11',
#  'pk22rd84',
#  'pk87rd24',
#  'pk61rd8',
#  'pk19rd18',
#  'pk1rd25',
#  'pk53rd37',
#  'pk49rd69',
#  'pk77rd95',
#  'pk54rd99',
#  'pk7rd11',
#  'pk61rd23',
#  'pk21rd68',
#  'pk20rd54',
#  'pk2rd21',
#  'pk85rd83',
#  'pk19rd41',
#  'pk41rd3',
#  'pk42rd4',
#  'pk31rd12',
#  'pk44rd13',
#  'pk76rd29',
#  'pk74rd92',
#  'pk98rd61',
#  'pk75rd93',
#  'pk63rd15',
#  'pk7rd58',
#  'pu13wh45',
#  'pu1wh10',
#  'pu2wh14',
#  'pu5wh10',
#  'pu99wh65',
#  'pu97wh63',
#  'pu11wh43',
#  'pu96wh62',
#  'pu45wh9',
#  'pu69wh47',
#  'pu62wh1',
#  'pu3wh19',
#  'pu94wh42',
#  'pu93wh41',
#  'pu100wh66',
#  'pu46wh10',
#  'pu12wh44',
#  'pu95wh61',
#  'pu98wh64',
#  'pu67wh40',
#  'bk97bk86',
#  'bk9bk8',
#  'bk93bk97',
#  'bk70bk62',
#  'bk67bk95',
#  'bk86bk62',
#  'bk15bk19',
#  'bk79bk76',
#  'bk69bk7',
#  'gr61',
#  'br87',
#  'br88',
#  'pu87ye39',
#  'pu45ye53',
#  'pu98ye9',
#  'br40',
#  'br39',
#  'wh71br49',
#  'pu3ye40',
#  'pu1ye38',
#  'ye54br83',
#  'pu23ye14',
#  'ye42br53',
#  'pu8br9',
#  'pu4br7',
#  'pu5br2',
#  'pu13ye5',
#  'pu6br8',
#  'ye100br9',
#  'ye39br51',
#  'pu8br88',
#  'ye61br52',
#  'wh72pk10',
#  'wh5pk79',
#  'wh45pk27',
#  'wh2pk4',
#  'wh78pk96',
#  'wh61pk99',
#  'wh71pk34',
#  'wh83pk76',
#  'wh68pk23',
#  'wh22pk15',
#  'wh48pk7',
#  'wh34pk92',
#  'wh23pk100',
#  'wh48pk16',
#  'wh51pk72',
#  'wh72pk25',
#  'wh32pk76',
#  'wh25pk11',
#  'wh34pk13',
#  'wh45pk73',
#  'wh41pk45',
#  'wh77pk46',
#  'wh1pk14',
#  'wh44pk44',
#  'wh49pk19',
#  'wh33pk33',
#  'wh39pk19',
#  'wh96pk45',
#  'wh24pk92',
#  'br7',
#  'bu64br50',
#  'bu31br97',
#  'bu3br81',
#  'br97',
#  'wh43or32',
#  'wh6or13',
#  'wh76or56',
#  'wh66or61',
#  'wh26or16',
#  'wh80or57',
#  'wh89or12',
#  'wh66or79',
#  'wh51or57',
#  'wh21or97',
#  'wh64or55',
#  'or86wh8',
#  'wh37or29',
#  'wh7or91',
#  'wh7or39',
#  'wh51or59',
#  'wh21or99',
#  'wh80or82',
#  'wh51or31',
#  'wh7or55',
#  'wh54or18',
#  'wh58or62',
#  'wh47or16',
#  'wh64or100',
#  'wh67or80',
#  'wh39or13',
#  'wh65or78',
#  'wh67or29',
#  'wh10or15',
#  'wh79or56',
#  'wh9or17',
#  'wh14or48',
#  'wh62or41',
#  'wh94or25',
#  'wh52or58',
#  'wh19or81',
#  'wh40or14',
#  'wh89or65',
#  'wh34or100',
#  'wh5or8',
#  'or34pu9',
#  'or73pu40',
#  'or100pu66',
#  'or36pu35',
#  'or100pu59',
#  'or76pu94',
#  'or12pu47',
#  'or26pu89',
#  'or74pu64',
#  'or46pu37',
#  'or51pu71',
#  'or40pu50',
#  'or48pu16',
#  'or9pu92',
#  'or64pu11',
#  'or40pu57',
#  'or2pu54',
#  'or13pu48',
#  'or47pu71',
#  'or74pu15',
#  'or11pu46',
#  'or37pu44',
#  'or35pu19',
#  'or34pu12',
#  'or100pu10',
#  'or39pu49',
#  'or38pu45',
#  'or91pu13',
#  'or60pu26',
#  'or44pu93',
#  'or47pu91',
#  'or85pu65',
#  'ye1br480',
#  'rd2pu22',
#  'rd65pu23',
#  'rd56pu21',
#  'bk52wh11',
#  'bk57wh35',
#  'bk83wh27',
#  'bk5wh3',
#  'bk53wh12',
#  'bk69wh31',
#  'bk47',
#  'bk48wh74',
#  'bk4wh78',
#  'bk50wh18',
#  'bk44wh46',
#  'bk65wh93',
#  'bk52wh54',
#  'bk66wh37',
#  'bk91wh60',
#  'bk68wh94',
#  'bk58wh36',
#  'bk100wh100',
#  'bk65wh20',
#  'bk59wh37',
#  'bk18',
#  'bk2wh3',
#  'bk54wh13',
#  'bk53wh33',
#  'bk43wh36',
#  'bk62wh44',
#  'bk43wh1',
#  'bk80wh28',
#  'bk64wh95',
#  'bk56wh34',
#  'bk3wh36',
#  'bk23wh94',
#  'or15bk34',
#  'or66bk72',
#  'or60bk10',
#  'ye43ye42',
#  'or13bk32',
#  'or85bk24',
#  'or9bk50',
#  'or46bk78',
#  'ye12ye11',
#  'or54bk58',
#  'or82bk72',
#  'or52bk56',
#  'or30bk18',
#  'or55bk59',
#  'or32bk42',
#  'or8bk49',
#  'or76bk11',
#  'or87bk66',
#  'or14bk33',
#  'or34bk43',
#  'or88bk67',
#  'or65bk22',
#  'or31bk41',
#  'or21bk87',
#  'or23bk79',
#  'or89bk70',
#  'or1bk23',
#  'or33bk81',
#  'or100bk91',
#  'or53bk57',
#  'or65bk100',
#  'or29bk62',
#  'or57bk16',
#  'or26bk46',
#  'ye22ye23',
#  'or56bk20',
#  'or18bk89',
#  'or37bk83',
#  'or17bk88',
#  'or10bk90',
#  'or36bk43',
#  'pu9ye55',
#  'pu90ye78',
#  'pu8ye53',
#  'pu53ye83',
#  'pu63ye77',
#  'pu52ye75',
#  'pu11ye41',
#  'pu10ye54',
#  'pu87ye79',
#  'pu37ye7',
#  'pu73ye73',
#  'pu84ye10',
#  'pu85ye9',
#  'pu59ye95',
#  'or44pu97',
#  'or83pu67',
#  'or96pu25',
#  'or81pu59',
#  'or85pu26',
#  'or10pu43',
#  'or24pu80',
#  'or40pu40',
#  'or99pu49',
#  'or39pu39',
#  'or11pu20',
#  'or97pu55',
#  'or94pu23',
#  'or97pu96',
#  'or46pu99',
#  'or98pu97',
#  'or92pu44',
#  'or93pu22',
#  'or97pu47',
#  'or45pu98',
#  'or2pu68',
#  'or8pu41',
#  'or47pu100',
#  'or95pu24',
#  'or82pu60',
#  'or22pu78',
#  'or30pu100',
#  'or21pu77',
#  'or9pu42',
#  'or98pu48',
#  'or98pu56',
#  'or86pu27',
#  'or100pu99',
#  'or99pu98',
#  'or99pu57',
#  'or62pu60',
#  'or100pu58',
#  'or94pu55',
#  'or38pu38',
#  'or85pu96',
#  'or92pu21',
#  'or61pu59',
#  'or33pu79',
#  'or34pu80',
#  'or32pu78',
#  'or100pu50',
#  'or23pu79',
#  'or84pu95',
#  'rd24gr82',
#  'rd18gr37',
#  'rd17gr84',
#  'rd36gr39',
#  'rd37gr7',
#  'rd39gr39',
#  'rd30gr38',
#  'rd18gr85',
#  'rd38gr6',
#  'rd36gr92',
#  'rd84gr3',
#  'rd28gr49',
#  'rd2gr96',
#  'rd13gr97',
#  'rd58gr48',
#  'rd99gr13',
#  'rd3gr74',
#  'rd38gr36',
#  'rd30gr5',
#  'rd12gr22',
#  'rd3gr35',
#  'rd15gr82',
#  'rd35gr14',
#  'rd4gr9',
#  'rd4gr90',
#  'rd57gr34',
#  'rd70gr7',
#  'rd12gr98',
#  'rd5gr49',
#  'rd29gr89',
#  'rd40gr4',
#  'rd38gr49',
#  'rd100gr25',
#  'rd28gr2',
#  'rd65gr88',
#  'rd29gr50',
#  'rd9gr81',
#  'rd15gr34',
#  'rd16gr83',
#  'rd39gr5',
#  'rd57gr61',
#  'rd19gr19',
#  'rd17gr36',
#  'rd61gr39',
#  'wh75wh5',
#  'wh77wh7',
#  'wh76wh6',
#  'wh78wh8',
#  'gr31bu90',
#  'gr91bu49',
#  'gr58bu39',
#  'gr2bu30',
#  'gr77bu36',
#  'gr55bu79',
#  'gr90bu7',
#  'gr58bu76',
#  'gr87bu36',
#  'gr16bu54',
#  'gr83bu51',
#  'gr57bu40',
#  'gr22bu96',
#  'gr33bu95',
#  'gr98bu75',
#  'gr49bu6',
#  'gr97bu74',
#  'gr100bu40',
#  'gr95bu72',
#  'gr59bu61',
#  'gr4bu87',
#  'gr60bu94',
#  'gr14bu51',
#  'gr45bu2',
#  'gr3bu88',
#  'gr5bu93',
#  'gr99bu90',
#  'gr55bu22',
#  'gr76bu28',
#  'gr83bu87',
#  'gr80bu23',
#  'gr15bu53',
#  'gr83bu89',
#  'gr46bu84',
#  'gr56bu30',
#  'gr77bu29',
#  'gr78bu30',
#  'gr58bu60',
#  'gr5bu54',
#  'gr17bu29',
#  'gr54bu78',
#  'gr9bu86',
#  'gr6bu6',
#  'gr57bu24',
#  'gr60bu62',
#  'gr10bu9',
#  'gr6bu55',
#  'gr53bu76',
#  'gr58bu93',
#  'gr59bu80',
#  'gr75bu19',
#  'gr68bu58',
#  'gr32bu94',
#  'gr96bu73',
#  'gr87bu87',
#  'gr7bu56',
#  'gr69bu59',
#  'gr89bu59',
#  'gr18bu69',
#  'gr15bu10',
#  'gr56bu51',
#  'gr83bu67',
#  'gr17bu55',
#  'gr46bu3',
#  'gr58bu25',
#  'gr1bu23',
#  'gr56bu23',
#  'gr95bu66',
#  'gr47bu4',
#  'gr48bu5',
#  'gr3bu36',
#  'gr60bu87',
#  'gr67bu57',
#  'gr92bu66',
#  'gr34bu97',
#  'gr74bu97',
#  'gr78bu37',
#  'gr70bu25',
#  'gr80bu39',
#  'gr79bu38',
#  'gr81bu85',
#  'gr54bu38',
#  'gr79bu90',
#  'gr89bu92',
#  'gr82bu86',
#  'gr32bu70',
#  'gr100bu95',
#  'gr70bu60',
#  'gr76bu35',
#  'rd37wh67',
#  'rd97wh82',
#  'rd8wh70',
#  'rd100wh57',
#  'rd34wh99',
#  'rd40wh70',
#  'rd81wh12',
#  'rd99wh56',
#  'rd33wh98',
#  'rd38wh68',
#  'rd32wh97',
#  'rd15wh35',
#  'rd14wh34',
#  'rd37wh40',
#  'rd36wh66',
#  'rd35wh39',
#  'rd39wh69',
#  'rd31wh96',
#  'rd16wh36',
#  'rd82wh13',
#  'rd7wh50',
#  'rd57wh66',
#  'rd13wh33',
#  'rd28wh47',
#  'rd96wh81',
#  'rd34wh38',
#  'rd27wh46',
#  'rd9wh90',
#  'or89pu49',
#  'or90pu50',
#  'or88pu48',
#  'or79pu5',
#  'or87pu47',
#  'or78pu4']

# %%
# double check that the birds subsetted here accurately capture the gmm birds (I think it should!)
# only about half of gmm birds were in the original spreadsheet

# %%
# home reared counterparts to xfosters from big families
len(list(home_reared_subset['Bird Name']))
# Out:
# 726

# %%
# xfosters from big families
len(list(valid_male_xfosters_from_big_families['Bird Name']))
# Out:
# 80

# %%
# genetic fathers
len(fathers_gen_sorted)
# Out:
# 13

# %%
# nest fathers
len(fathers_nest_sorted)
# Out:
# 15

# %%
# birds from gmm data
print(len(missing_birds))
print(len(overlap_birds))
# Out:
# 95
# 74

# %%
from tools.dbquery import getAllBirdsFromDB
import sqlite3

con = sqlite3.connect('../refs/2026-01-15-db.sqlite3')
cur = con.cursor()

all_birds_in_db = getAllBirdsFromDB(cur)
all_birds_in_db_name = []
for bird in all_birds_in_db:
    bndcolor1=bird[1]
    bndnum1=bird[2]
    bndcolor2=bird[4]
    bndnum2=bird[5]
    all_birds_in_db_name.append(f'{bndcolor1}{bndnum1}{bndcolor2}{bndnum2}')

# %%
are_missing_birds_in_db_at_all = {}
for bird in missing_birds:
    if bird in all_birds_in_db_name:
        are_missing_birds_in_db_at_all[bird] = True
    else:
        are_missing_birds_in_db_at_all[bird] = False

print(are_missing_birds_in_db_at_all)
# Out:
# {'ye1': False, 'wh99pk7': True, 'wh94or25': True, 'wh89pk4': True, 'wh89or12': True, 'wh88pk84': True, 'wh83pk50': True, 'wh75pk99': True, 'wh70pk50': True, 'wh66pk94': True, 'wh61pk3': True, 'wh59pk66': True, 'wh54pk85': True, 'wh51or31': True, 'wh50pk34': True, 'wh3pk86': True, 'wh39or13': True, 'wh35pk25': True, 'wh28pk28': True, 'wh23pk78': True, 'wh11pk95': True, 'rd94wh47': True, 'rd93wh64': True, 'rd88wh69': True, 'rd7wh75': True, 'rd78wh86': True, 'rd78wh62': True, 'rd70wh90': True, 'rd58wh32': True, 'rd4wh53': True, 'rd3wh90': True, 'rd34wh20': True, 'rd26wh66': True, 'rd22wh20': True, 'pu88bk78': True, 'pu64wh91': True, 'pu62wh53': True, 'pu42bk10': True, 'pu31bk90': True, 'pu26wh18': True, 'pu25wh17': True, 'pu20wh66': True, 'pu1wh14': True, 'pu19wh65': True, 'pu16wh31': True, 'pk43gr64': True, 'pk1gr62': True, 'or41or32': True, 'or33or33': True, 'or28bu17': True, 'gr94gr1': True, 'gr85gr34': True, 'gr78gr76': True, 'gr70gr66': True, 'gr66gr43': True, 'gr65gr9': True, 'gr63gr76': True, 'gr57gr47': True, 'gr43gr62': True, 'gr38gr59': True, 'gr27gr28': True, 'gr25gr27': True, 'gr24gr26': True, 'bu95or85': True, 'bu92or63': True, 'bu91or64': True, 'bu82or62': True, 'bu81or63': True, 'bu71or60': True, 'bu69or87': True, 'bu66or8': True, 'bu65or7': True, 'bu50or44': True, 'bu49or82': True, 'bu48or83': True, 'bu21or96': True, 'bu17or20': True, 'bu11or68': True, 'bk9bk8': True, 'bk86bk62': True, 'bk84bk85': True, 'bk79bk82': True, 'bk64bk65': True, 'bk5bk25': True, 'bk51bk59': True, 'bk50bk49': True, 'bk4bk95': True, 'bk47bk40': True, 'bk34bk33': True, 'bk2bk10': True, 'bk29bk8': True, 'bk28bk68': True, 'bk20bk45': True, 'bk1bk9': True, 'bk100bk99': True}

# %%
list_of_birds_for_analysis = list(valid_male_xfosters_from_big_families['Bird Name']) + list(fathers_gen_sorted) + list(fathers_nest_sorted)

# %%
list_of_birds_for_analysis
# Out:
# ['wh15wh94',
#  'wh14wh93',
#  'wh50wh90',
#  'wh49wh89',
#  'wh47wh87',
#  'wh48wh88',
#  'bu26wh39',
#  'bu25wh38',
#  'bu82wh76',
#  'rd39wh3',
#  'rd40wh4',
#  'bu9wh89',
#  'bu10wh90',
#  'bu7wh87',
#  'rd33wh42',
#  'rd25wh57',
#  'gr6gr5',
#  'ye30ye82',
#  'ye23ye43',
#  'rd42pu47',
#  'rd43pu46',
#  'rd50gr1',
#  'rd39gr23',
#  'bk45wh59',
#  'wh86or19',
#  'wh85or81',
#  'wh82or15',
#  'wh83or16',
#  'rd77wh77',
#  'bk24wh25',
#  'bk100wh89',
#  'bk17wh56',
#  'bk81wh20',
#  'bk79wh14',
#  'bk38bk39',
#  'bk4bk47',
#  'bk36bk37',
#  'bk83bk73',
#  'bk94bk87',
#  'bk67bk44',
#  'bk76bk63',
#  'bk75bk62',
#  'bk43bk70',
#  'bk13bk12',
#  'bk41bk14',
#  'pk61bk8',
#  'pk15bk43',
#  'pu57wh52',
#  'pu55wh32',
#  'ye92br4',
#  'ye93br5',
#  'ye91br6',
#  'bk34bk51',
#  'bk73bk71',
#  'bk1bk3',
#  'bk91wh31',
#  'bk61wh42',
#  'bk63wh43',
#  'pu1wh51',
#  'wh93pk62',
#  'wh91pk61',
#  'pk6bk65',
#  'pk37bk19',
#  'pk46bk46',
#  'bk40wh47',
#  'pu31br476',
#  'pu33br479',
#  'pk5bk39',
#  'pk2bk37',
#  'pu58br33',
#  'pu55br34',
#  'pu22wh17',
#  'pk1bk31',
#  'pk43bk33',
#  'pu51wh43',
#  'pu71wh42',
#  'pu39wh79',
#  'bk13wh63',
#  'bk72wh64',
#  'bk74wh76',
#  'bu34or18',
#  'pk24bu3',
#  'pk72bk90',
#  'pk85gr19',
#  'pk97rd22',
#  'pu11bk85',
#  'pu42wh35',
#  'pu91wh67',
#  'rd75wh72',
#  'wh71br49',
#  'wh88br85',
#  'ye1tut0',
#  'ye81br444',
#  'bk1bk3',
#  'bk34bk51',
#  'bk37wh86',
#  'bu10wh86',
#  'bu24wh84',
#  'bu7wh67',
#  'gr73gr72',
#  'gr99or87',
#  'or10bk88',
#  'pk100bk68',
#  'pk24bu3',
#  'pu23wh38',
#  'pu35wh17',
#  'rd81wh45',
#  'ye25']
